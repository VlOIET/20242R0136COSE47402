# %% [markdown]
# ### (1) SET Environment

# %%
""" conda install pytorch torchvision torchaudio pytorch-cuda=12.1 -c pytorch -c nvidia """
# Out:
# ' conda install pytorch torchvision torchaudio pytorch-cuda=12.1 -c pytorch -c nvidia '

# %%
pip install transformers
# Out:
# ' pip install transformers '

# %%
pip install -U ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XM87RY8f7oIaykIwsDoU")
project = rf.workspace("labelling-ygqlj").project("food-i6tfy")
version = project.version(14)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ## (2) Training

# %%
#Environment
DEVICE = "cuda"
DATA_PATH = "C:/Users/hyunz/miniconda3/envs/DFP/code/asdfdasfsa.jpeg"
MODEL_NAME = "1201best.pt"

#Train
BATCH_SIZE = 16
EPOCHS = 5
LR = 5e-5

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# 모델 로드
model = YOLO(MODEL_NAME)

# 예측 수행
results = model.predict(DATA_PATH)

# 예측 결과 이미지
res_plot = results[0].plot()

# Matplotlib로 이미지 출력
plt.imshow(cv2.cvtColor(res_plot, cv2.COLOR_BGR2RGB))  # OpenCV는 BGR 형식이므로 RGB로 변환
plt.axis('off')  # 축 숨기기
plt.show()
# Out:
# image 1/1 C:\Users\hyunz\miniconda3\envs\DFP\code\asdfdasfsa.jpeg: 544x640 1 Mushroom, 31.0ms
# Speed: 4.4ms preprocess, 31.0ms inference, 134.0ms postprocess per image at shape (1, 3, 544, 640)
